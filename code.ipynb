# %%
#importing libraries and modules
import numpy as np
import pandas as pd
from sklearn.preprocessing import FunctionTransformer
from sklearn.pipeline import Pipeline, make_pipeline
from xgboost import XGBRegressor
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV

# %%
df = pd.read_csv('train.csv')

# %%
df1 = df.drop(['SalePrice'],axis = 1)

# %%
df1.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC Fence MiscFeature  \
# 0         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 1         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 2         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 3         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 4         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0       0      2    2008        WD         Normal
# 1       0      5    2007        WD         Normal
# 2       0      9    2008        WD         Normal
# 3       0      2    2006        WD        Abnorml
# 4       0     12    2008        WD         Normal
#
# [5 rows x 80 columns]

# %%
insignificant_col = list(df.corr()['SalePrice'][(df.corr()['SalePrice']<0.1) & (df.corr()['SalePrice']>-0.1)].index)

# %%
insignificant_col
# Out:
# ['Id',
#  'MSSubClass',
#  'OverallCond',
#  'BsmtFinSF2',
#  'LowQualFinSF',
#  'BsmtHalfBath',
#  '3SsnPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold']

# %%
# removing features with low correlation
def drop_insignificant_col(data):
    data.drop(insignificant_col,axis =1,inplace = True)  
    return data

# %%
drop_insignificant_col(df1)
# Out:
#      MSZoning  LotFrontage  LotArea Street Alley LotShape LandContour  \
# 0          RL         65.0     8450   Pave   NaN      Reg         Lvl
# 1          RL         80.0     9600   Pave   NaN      Reg         Lvl
# 2          RL         68.0    11250   Pave   NaN      IR1         Lvl
# 3          RL         60.0     9550   Pave   NaN      IR1         Lvl
# 4          RL         84.0    14260   Pave   NaN      IR1         Lvl
# ...       ...          ...      ...    ...   ...      ...         ...
# 1455       RL         62.0     7917   Pave   NaN      Reg         Lvl
# 1456       RL         85.0    13175   Pave   NaN      Reg         Lvl
# 1457       RL         66.0     9042   Pave   NaN      Reg         Lvl
# 1458       RL         68.0     9717   Pave   NaN      Reg         Lvl
# 1459       RL         75.0     9937   Pave   NaN      Reg         Lvl
#
#      Utilities LotConfig LandSlope  ... PavedDrive WoodDeckSF OpenPorchSF  \
# 0       AllPub    Inside       Gtl  ...          Y          0          61
# 1       AllPub       FR2       Gtl  ...          Y        298           0
# 2       AllPub    Inside       Gtl  ...          Y          0          42
# 3       AllPub    Corner       Gtl  ...          Y          0          35
# 4       AllPub       FR2       Gtl  ...          Y        192          84
# ...        ...       ...       ...  ...        ...        ...         ...
# 1455    AllPub    Inside       Gtl  ...          Y          0          40
# 1456    AllPub    Inside       Gtl  ...          Y        349           0
# 1457    AllPub    Inside       Gtl  ...          Y          0          60
# 1458    AllPub    Inside       Gtl  ...          Y        366           0
# 1459    AllPub    Inside       Gtl  ...          Y        736          68
#
#      EnclosedPorch ScreenPorch  PoolQC  Fence  MiscFeature SaleType  \
# 0                0           0     NaN    NaN          NaN       WD
# 1                0           0     NaN    NaN          NaN       WD
# 2                0           0     NaN    NaN          NaN       WD
# 3              272           0     NaN    NaN          NaN       WD
# 4                0           0     NaN    NaN          NaN       WD
# ...            ...         ...     ...    ...          ...      ...
# 1455             0           0     NaN    NaN          NaN       WD
# 1456             0           0     NaN  MnPrv          NaN       WD
# 1457             0           0     NaN  GdPrv         Shed       WD
# 1458           112           0     NaN    NaN          NaN       WD
# 1459             0           0     NaN    NaN          NaN       WD
#
#      SaleCondition
# 0           Normal
# 1           Normal
# 2           Normal
# 3          Abnorml
# 4           Normal
# ...            ...
# 1455        Normal
# 1456        Normal
# 1457        Normal
# 1458        Normal
# 1459        Normal
#
# [1460 rows x 69 columns]

# %%
df1.isnull().sum().sort_values(ascending = False).head(20)
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# FireplaceQu      690
# LotFrontage      259
# GarageCond        81
# GarageFinish      81
# GarageQual        81
# GarageYrBlt       81
# GarageType        81
# BsmtFinType2      38
# BsmtExposure      38
# BsmtCond          37
# BsmtQual          37
# BsmtFinType1      37
# MasVnrArea         8
# MasVnrType         8
# Electrical         1
# 2ndFlrSF           0
# dtype: int64

# %%
# removing features having too many NaN values
def droping_high_missing_features(data):
    data.drop(['PoolQC','MiscFeature','Alley','Fence','FireplaceQu','LotFrontage'],axis = 1,inplace = True)
    return data

# %%
droping_high_missing_features(df1)
# Out:
#      MSZoning  LotArea Street LotShape LandContour Utilities LotConfig  \
# 0          RL     8450   Pave      Reg         Lvl    AllPub    Inside
# 1          RL     9600   Pave      Reg         Lvl    AllPub       FR2
# 2          RL    11250   Pave      IR1         Lvl    AllPub    Inside
# 3          RL     9550   Pave      IR1         Lvl    AllPub    Corner
# 4          RL    14260   Pave      IR1         Lvl    AllPub       FR2
# ...       ...      ...    ...      ...         ...       ...       ...
# 1455       RL     7917   Pave      Reg         Lvl    AllPub    Inside
# 1456       RL    13175   Pave      Reg         Lvl    AllPub    Inside
# 1457       RL     9042   Pave      Reg         Lvl    AllPub    Inside
# 1458       RL     9717   Pave      Reg         Lvl    AllPub    Inside
# 1459       RL     9937   Pave      Reg         Lvl    AllPub    Inside
#
#      LandSlope Neighborhood Condition1  ... GarageArea GarageQual GarageCond  \
# 0          Gtl      CollgCr       Norm  ...        548         TA         TA
# 1          Gtl      Veenker      Feedr  ...        460         TA         TA
# 2          Gtl      CollgCr       Norm  ...        608         TA         TA
# 3          Gtl      Crawfor       Norm  ...        642         TA         TA
# 4          Gtl      NoRidge       Norm  ...        836         TA         TA
# ...        ...          ...        ...  ...        ...        ...        ...
# 1455       Gtl      Gilbert       Norm  ...        460         TA         TA
# 1456       Gtl       NWAmes       Norm  ...        500         TA         TA
# 1457       Gtl      Crawfor       Norm  ...        252         TA         TA
# 1458       Gtl        NAmes       Norm  ...        240         TA         TA
# 1459       Gtl      Edwards       Norm  ...        276         TA         TA
#
#       PavedDrive  WoodDeckSF  OpenPorchSF EnclosedPorch ScreenPorch SaleType  \
# 0              Y           0           61             0           0       WD
# 1              Y         298            0             0           0       WD
# 2              Y           0           42             0           0       WD
# 3              Y           0           35           272           0       WD
# 4              Y         192           84             0           0       WD
# ...          ...         ...          ...           ...         ...      ...
# 1455           Y           0           40             0           0       WD
# 1456           Y         349            0             0           0       WD
# 1457           Y           0           60             0           0       WD
# 1458           Y         366            0           112           0       WD
# 1459           Y         736           68             0           0       WD
#
#      SaleCondition
# 0           Normal
# 1           Normal
# 2           Normal
# 3          Abnorml
# 4           Normal
# ...            ...
# 1455        Normal
# 1456        Normal
# 1457        Normal
# 1458        Normal
# 1459        Normal
#
# [1460 rows x 63 columns]

# %%
from pandas.api.types import is_numeric_dtype

# %%
num_cols = []
cat_cols = []
for col in df1.columns:
    if (is_numeric_dtype(df1[col]) and df1[col].nunique() >= 25):
        num_cols.append(col)
    else:
        cat_cols.append(col)

# %%
#checking for high correlation among features
((df1.corr()>0.9) |(df1.corr()<-0.9)).sum()
# Out:
# LotArea          1
# OverallQual      1
# YearBuilt        1
# YearRemodAdd     1
# MasVnrArea       1
# BsmtFinSF1       1
# BsmtUnfSF        1
# TotalBsmtSF      1
# 1stFlrSF         1
# 2ndFlrSF         1
# GrLivArea        1
# BsmtFullBath     1
# FullBath         1
# HalfBath         1
# BedroomAbvGr     1
# KitchenAbvGr     1
# TotRmsAbvGrd     1
# Fireplaces       1
# GarageYrBlt      1
# GarageCars       1
# GarageArea       1
# WoodDeckSF       1
# OpenPorchSF      1
# EnclosedPorch    1
# ScreenPorch      1
# dtype: int64

# %%
invariable_cat_cols = []
for col in cat_cols:
    if df1[col].value_counts().max()/df1.shape[0]*100 > 90:
        invariable_cat_cols.append(col)

# %%
# removing categorical features which vary less frequently
def remove_invariable_cols(data):
    data.drop(invariable_cat_cols,axis = 1,inplace = True)
    return data

# %%
remove_invariable_cols(df1)
# Out:
#      MSZoning  LotArea LotShape LandContour LotConfig Neighborhood Condition1  \
# 0          RL     8450      Reg         Lvl    Inside      CollgCr       Norm
# 1          RL     9600      Reg         Lvl       FR2      Veenker      Feedr
# 2          RL    11250      IR1         Lvl    Inside      CollgCr       Norm
# 3          RL     9550      IR1         Lvl    Corner      Crawfor       Norm
# 4          RL    14260      IR1         Lvl       FR2      NoRidge       Norm
# ...       ...      ...      ...         ...       ...          ...        ...
# 1455       RL     7917      Reg         Lvl    Inside      Gilbert       Norm
# 1456       RL    13175      Reg         Lvl    Inside       NWAmes       Norm
# 1457       RL     9042      Reg         Lvl    Inside      Crawfor       Norm
# 1458       RL     9717      Reg         Lvl    Inside        NAmes       Norm
# 1459       RL     9937      Reg         Lvl    Inside      Edwards       Norm
#
#      BldgType HouseStyle  OverallQual  ...  GarageFinish  GarageCars  \
# 0        1Fam     2Story            7  ...           RFn           2
# 1        1Fam     1Story            6  ...           RFn           2
# 2        1Fam     2Story            7  ...           RFn           2
# 3        1Fam     2Story            7  ...           Unf           3
# 4        1Fam     2Story            8  ...           RFn           3
# ...       ...        ...          ...  ...           ...         ...
# 1455     1Fam     2Story            6  ...           RFn           2
# 1456     1Fam     1Story            6  ...           Unf           2
# 1457     1Fam     2Story            7  ...           RFn           1
# 1458     1Fam     1Story            5  ...           Unf           1
# 1459     1Fam     1Story            5  ...           Fin           1
#
#      GarageArea GarageQual WoodDeckSF OpenPorchSF  EnclosedPorch ScreenPorch  \
# 0           548         TA          0          61              0           0
# 1           460         TA        298           0              0           0
# 2           608         TA          0          42              0           0
# 3           642         TA          0          35            272           0
# 4           836         TA        192          84              0           0
# ...         ...        ...        ...         ...            ...         ...
# 1455        460         TA          0          40              0           0
# 1456        500         TA        349           0              0           0
# 1457        252         TA          0          60              0           0
# 1458        240         TA        366           0            112           0
# 1459        276         TA        736          68              0           0
#
#      SaleType SaleCondition
# 0          WD        Normal
# 1          WD        Normal
# 2          WD        Normal
# 3          WD       Abnorml
# 4          WD        Normal
# ...       ...           ...
# 1455       WD        Normal
# 1456       WD        Normal
# 1457       WD        Normal
# 1458       WD        Normal
# 1459       WD        Normal
#
# [1460 rows x 51 columns]

# %%
# filling the null values
def imputation(data):
    for col in num_cols:
        imp_value = data[col].mean()
        data[col] = data[col].fillna(imp_value)
    for col in cat_cols:
        if col not in invariable_cat_cols:
            imp_value = data[col].value_counts().idxmax()
            data[col] = data[col].fillna(imp_value)
    return data

# %%
imputation(df1)
# Out:
#      MSZoning  LotArea LotShape LandContour LotConfig Neighborhood Condition1  \
# 0          RL     8450      Reg         Lvl    Inside      CollgCr       Norm
# 1          RL     9600      Reg         Lvl       FR2      Veenker      Feedr
# 2          RL    11250      IR1         Lvl    Inside      CollgCr       Norm
# 3          RL     9550      IR1         Lvl    Corner      Crawfor       Norm
# 4          RL    14260      IR1         Lvl       FR2      NoRidge       Norm
# ...       ...      ...      ...         ...       ...          ...        ...
# 1455       RL     7917      Reg         Lvl    Inside      Gilbert       Norm
# 1456       RL    13175      Reg         Lvl    Inside       NWAmes       Norm
# 1457       RL     9042      Reg         Lvl    Inside      Crawfor       Norm
# 1458       RL     9717      Reg         Lvl    Inside        NAmes       Norm
# 1459       RL     9937      Reg         Lvl    Inside      Edwards       Norm
#
#      BldgType HouseStyle  OverallQual  ...  GarageFinish  GarageCars  \
# 0        1Fam     2Story            7  ...           RFn           2
# 1        1Fam     1Story            6  ...           RFn           2
# 2        1Fam     2Story            7  ...           RFn           2
# 3        1Fam     2Story            7  ...           Unf           3
# 4        1Fam     2Story            8  ...           RFn           3
# ...       ...        ...          ...  ...           ...         ...
# 1455     1Fam     2Story            6  ...           RFn           2
# 1456     1Fam     1Story            6  ...           Unf           2
# 1457     1Fam     2Story            7  ...           RFn           1
# 1458     1Fam     1Story            5  ...           Unf           1
# 1459     1Fam     1Story            5  ...           Fin           1
#
#      GarageArea GarageQual WoodDeckSF OpenPorchSF  EnclosedPorch ScreenPorch  \
# 0           548         TA          0          61              0           0
# 1           460         TA        298           0              0           0
# 2           608         TA          0          42              0           0
# 3           642         TA          0          35            272           0
# 4           836         TA        192          84              0           0
# ...         ...        ...        ...         ...            ...         ...
# 1455        460         TA          0          40              0           0
# 1456        500         TA        349           0              0           0
# 1457        252         TA          0          60              0           0
# 1458        240         TA        366           0            112           0
# 1459        276         TA        736          68              0           0
#
#      SaleType SaleCondition
# 0          WD        Normal
# 1          WD        Normal
# 2          WD        Normal
# 3          WD       Abnorml
# 4          WD        Normal
# ...       ...           ...
# 1455       WD        Normal
# 1456       WD        Normal
# 1457       WD        Normal
# 1458       WD        Normal
# 1459       WD        Normal
#
# [1460 rows x 51 columns]

# %%
df2 = df.copy()

# %%
drop_insignificant_col(df2)
droping_high_missing_features(df2)
remove_invariable_cols(df2)
imputation(df2)
# Out:
#      MSZoning  LotArea LotShape LandContour LotConfig Neighborhood Condition1  \
# 0          RL     8450      Reg         Lvl    Inside      CollgCr       Norm
# 1          RL     9600      Reg         Lvl       FR2      Veenker      Feedr
# 2          RL    11250      IR1         Lvl    Inside      CollgCr       Norm
# 3          RL     9550      IR1         Lvl    Corner      Crawfor       Norm
# 4          RL    14260      IR1         Lvl       FR2      NoRidge       Norm
# ...       ...      ...      ...         ...       ...          ...        ...
# 1455       RL     7917      Reg         Lvl    Inside      Gilbert       Norm
# 1456       RL    13175      Reg         Lvl    Inside       NWAmes       Norm
# 1457       RL     9042      Reg         Lvl    Inside      Crawfor       Norm
# 1458       RL     9717      Reg         Lvl    Inside        NAmes       Norm
# 1459       RL     9937      Reg         Lvl    Inside      Edwards       Norm
#
#      BldgType HouseStyle  OverallQual  ...  GarageCars  GarageArea GarageQual  \
# 0        1Fam     2Story            7  ...           2         548         TA
# 1        1Fam     1Story            6  ...           2         460         TA
# 2        1Fam     2Story            7  ...           2         608         TA
# 3        1Fam     2Story            7  ...           3         642         TA
# 4        1Fam     2Story            8  ...           3         836         TA
# ...       ...        ...          ...  ...         ...         ...        ...
# 1455     1Fam     2Story            6  ...           2         460         TA
# 1456     1Fam     1Story            6  ...           2         500         TA
# 1457     1Fam     2Story            7  ...           1         252         TA
# 1458     1Fam     1Story            5  ...           1         240         TA
# 1459     1Fam     1Story            5  ...           1         276         TA
#
#      WoodDeckSF OpenPorchSF EnclosedPorch  ScreenPorch SaleType SaleCondition  \
# 0             0          61             0            0       WD        Normal
# 1           298           0             0            0       WD        Normal
# 2             0          42             0            0       WD        Normal
# 3             0          35           272            0       WD       Abnorml
# 4           192          84             0            0       WD        Normal
# ...         ...         ...           ...          ...      ...           ...
# 1455          0          40             0            0       WD        Normal
# 1456        349           0             0            0       WD        Normal
# 1457          0          60             0            0       WD        Normal
# 1458        366           0           112            0       WD        Normal
# 1459        736          68             0            0       WD        Normal
#
#      SalePrice
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
# ...        ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
#
# [1460 rows x 52 columns]

# %%
#converting all categorical values to numbers
def target_encoding(data):
    for col in cat_cols:
        if col not in invariable_cat_cols:
            dict1 = df2.groupby(col)['SalePrice'].mean().to_dict()
            data[col] = data[col].map(dict1)
    return data

# %%
target_encoding(df1)
# Out:
#            MSZoning  LotArea       LotShape    LandContour      LotConfig  \
# 0     191004.994787     8450  164754.818378  180183.746758  176938.047529
# 1     191004.994787     9600  164754.818378  180183.746758  177934.574468
# 2     191004.994787    11250  206101.665289  180183.746758  176938.047529
# 3     191004.994787     9550  206101.665289  180183.746758  181623.425856
# 4     191004.994787    14260  206101.665289  180183.746758  177934.574468
# ...             ...      ...            ...            ...            ...
# 1455  191004.994787     7917  164754.818378  180183.746758  176938.047529
# 1456  191004.994787    13175  164754.818378  180183.746758  176938.047529
# 1457  191004.994787     9042  164754.818378  180183.746758  176938.047529
# 1458  191004.994787     9717  164754.818378  180183.746758  176938.047529
# 1459  191004.994787     9937  164754.818378  180183.746758  176938.047529
#
#        Neighborhood     Condition1       BldgType     HouseStyle  \
# 0     197965.773333  184495.492063  185763.807377  210051.764045
# 1     238772.727273  142475.481481  185763.807377  175985.477961
# 2     197965.773333  184495.492063  185763.807377  210051.764045
# 3     210624.725490  184495.492063  185763.807377  210051.764045
# 4     335295.317073  184495.492063  185763.807377  210051.764045
# ...             ...            ...            ...            ...
# 1455  192854.506329  184495.492063  185763.807377  210051.764045
# 1456  189050.068493  184495.492063  185763.807377  175985.477961
# 1457  210624.725490  184495.492063  185763.807377  210051.764045
# 1458  145847.080000  184495.492063  185763.807377  175985.477961
# 1459  128219.700000  184495.492063  185763.807377  175985.477961
#
#         OverallQual  ...   GarageFinish     GarageCars  GarageArea  \
# 0     207716.423197  ...  202068.869668  183851.663835         548
# 1     161603.034759  ...  202068.869668  183851.663835         460
# 2     207716.423197  ...  202068.869668  183851.663835         608
# 3     207716.423197  ...  137570.460641  309636.121547         642
# 4     274735.535714  ...  202068.869668  309636.121547         836
# ...             ...  ...            ...            ...         ...
# 1455  161603.034759  ...  202068.869668  183851.663835         460
# 1456  161603.034759  ...  137570.460641  183851.663835         500
# 1457  207716.423197  ...  202068.869668  128116.688347         252
# 1458  133523.347607  ...  137570.460641  128116.688347         240
# 1459  133523.347607  ...  240052.690341  128116.688347         276
#
#          GarageQual  WoodDeckSF  OpenPorchSF  EnclosedPorch  ScreenPorch  \
# 0     182591.864224           0           61              0            0
# 1     182591.864224         298            0              0            0
# 2     182591.864224           0           42              0            0
# 3     182591.864224           0           35            272            0
# 4     182591.864224         192           84              0            0
# ...             ...         ...          ...            ...          ...
# 1455  182591.864224           0           40              0            0
# 1456  182591.864224         349            0              0            0
# 1457  182591.864224           0           60              0            0
# 1458  182591.864224         366            0            112            0
# 1459  182591.864224         736           68              0            0
#
#            SaleType  SaleCondition
# 0     173401.836622  175202.219533
# 1     173401.836622  175202.219533
# 2     173401.836622  175202.219533
# 3     173401.836622  146526.623762
# 4     173401.836622  175202.219533
# ...             ...            ...
# 1455  173401.836622  175202.219533
# 1456  173401.836622  175202.219533
# 1457  173401.836622  175202.219533
# 1458  173401.836622  175202.219533
# 1459  173401.836622  175202.219533
#
# [1460 rows x 51 columns]

# %%
pipe = Pipeline([('classifier',XGBRegressor())])

# %%
grid_param = [
    {'classifier':[XGBRegressor()],
              'classifier__n_estimators':[50,100,200],
              'classifier__learning_rate':[0.03,0.1,0.3]           
    },    
    {'classifier':[Ridge()],
              'classifier__alpha':[0.01,0.3,1,3]               
    }
    
]

# %%
GScv2 = GridSearchCV(pipe,param_grid=grid_param,cv=5)

# %%
ft1 = FunctionTransformer(drop_insignificant_col)
ft2 = FunctionTransformer(droping_high_missing_features)
ft3 = FunctionTransformer(remove_invariable_cols)
ft4 = FunctionTransformer(imputation)
ft5 = FunctionTransformer(target_encoding)

# %%
pipe = make_pipeline(ft1,ft2,ft3,ft4,ft5,GScv2)

# %%
pipe.fit(df.drop('SalePrice',axis =1),df['SalePrice'])
# Out:
# Pipeline(steps=[('functiontransformer-1',
#                  FunctionTransformer(func=<function drop_insignificant_col at 0x0000018976728C10>)),
#                 ('functiontransformer-2',
#                  FunctionTransformer(func=<function droping_high_missing_features at 0x0000018976728CA0>)),
#                 ('functiontransformer-3',
#                  FunctionTransformer(func=<function remove_invariable_cols at 0x000001897676B040>)),
#                 ('functiontr...
#                                                                        max_depth=None,
#                                                                        max_leaves=None,
#                                                                        min_child_weight=None,
#                                                                        missing=nan,
#                                                                        monotone_constraints=None,
#                                                                        n_estimators=200,
#                                                                        n_jobs=None,
#                                                                        num_parallel_tree=None,
#                                                                        predictor=None,
#                                                                        random_state=None,
#                                                                        reg_alpha=None,
#                                                                        reg_lambda=None, ...)],
#                                            'classifier__learning_rate': [0.03,
#                                                                          0.1,
#                                                                          0.3],
#                                            'classifier__n_estimators': [50, 100,
#                                                                         200]},
#                                           {'classifier': [Ridge()],
#                                            'classifier__alpha': [0.01, 0.3, 1,
#                                                                  3]}]))])

# %%
df_test  = pd.read_csv('test.csv')

# %%
submission = df_test[['Id']]

# %%
pred = pipe.predict(df_test)

# %%
submission['SalePrice'] = pred
# Out:
# C:\Users\SAISUR~1\AppData\Local\Temp/ipykernel_11800/1671381796.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   submission['SalePrice'] = pred

# %%
submission
# Out:
#         Id      SalePrice
# 0     1461  121332.398438
# 1     1462  154711.140625
# 2     1463  186524.000000
# 3     1464  188210.796875
# 4     1465  188983.765625
# ...    ...            ...
# 1454  2915   78011.585938
# 1455  2916   84157.664062
# 1456  2917  147415.578125
# 1457  2918  118437.992188
# 1458  2919  196565.812500
#
# [1459 rows x 2 columns]

# %%
submission.to_csv('submission2.csv',index = False)
